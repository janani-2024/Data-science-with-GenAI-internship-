# %%
#problem 1
my_str="Hello, World!"
print(my_str)
# Out:
# Hello, World!

# %%
#problem 2
n=int(input("Enter an integer: "))
if n%2!=0:
    print("weird")
else:
    if 2<=n<=5:
        print("Not weird")
    elif 6<=n<=20:
        print("weird")
    elif n>20:
        print("Not weird")
# Out:
# Enter an integer:  3
# weird

# %%
#problem 3
a=int(input("Enter integer a: "))
b=int(input("Enter integer b: "))
print(a+b)
print(a-b)
print(a*b)
# Out:
# Enter integer a:  5
# Enter integer b:  10
# 15
# -5
# 50

# %%
#problem 4
a=int(input("Enter integer a: "))
b=int(input("Enter integer b: "))
print(a//b)
print(a/b)
# Out:
# Enter integer a:  1
# Enter integer b:  3
# 0
# 0.3333333333333333

# %%
#problem 5
n=int(input("enter an integer: "))
for i in range(n):
    print(i*i)
# Out:
# enter an integer:  5
# 0
# 1
# 4
# 9
# 16

# %%
#problem 6
def is_leap(year):
    if (year%400==0):
        return True
    elif (year%100==0):
        return False
    elif (year%4==0):
        return True
    else:
        return False
is_leap(2000)
# Out:
# True

# %%
#problem 7
n=int(input("Enter an integer:"))
i=1
num=0
while i<=n:
    num=num*10+i
    i+=1
print(num)
# Out:
# Enter an integer: 6
# 123456
